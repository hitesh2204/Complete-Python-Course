# %%
import pandas as pd

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv")
print(brick_df)
# Out:
#    ID       country    capital    area  population
# 0  BR        Brazil   Brasilia   8.516      200.40
# 1  RU        Russia     Moscow  17.100      143.50
# 2  IN         India  New Delhi   3.286     1252.00
# 3  CH         China    Beijing   9.597     1357.00
# 4  SA  South Africa   Pretoria   1.221       52.98

# %%
brick_df
# Out:
#    ID       country    capital    area  population
# 0  BR        Brazil   Brasilia   8.516      200.40
# 1  RU        Russia     Moscow  17.100      143.50
# 2  IN         India  New Delhi   3.286     1252.00
# 3  CH         China    Beijing   9.597     1357.00
# 4  SA  South Africa   Pretoria   1.221       52.98

# %%
type(brick_df)
# Out:
# pandas.core.frame.DataFrame

# %%
brick_df.columns
# Out:
# Index(['ID', 'country', 'capital', 'area', 'population'], dtype='object')

# %% [markdown]
# ## "nrows" to display number of rows from datasets.

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv",nrows=3)
print(brick_df)
# Out:
#    ID country    capital    area  population
# 0  BR  Brazil   Brasilia   8.516       200.4
# 1  RU  Russia     Moscow  17.100       143.5
# 2  IN   India  New Delhi   3.286      1252.0

# %% [markdown]
# ## "usecols" to read a specific columns fom datasets.

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv",usecols=[2,4])
print(brick_df)
# Out:
#      capital  population
# 0   Brasilia      200.40
# 1     Moscow      143.50
# 2  New Delhi     1252.00
# 3    Beijing     1357.00
# 4   Pretoria       52.98

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv")
print(brick_df)
# Out:
#    ID       country    capital    area  population
# 0  BR        Brazil   Brasilia   8.516      200.40
# 1  RU        Russia     Moscow  17.100      143.50
# 2  IN         India  New Delhi   3.286     1252.00
# 3  CH         China    Beijing   9.597     1357.00
# 4  SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# ## "Skiprows" parameter used to remove unwanted rows.

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv",skiprows=1)
print(brick_df)
# Out:
#    BR        Brazil   Brasilia   8.516    200.4
# 0  RU        Russia     Moscow  17.100   143.50
# 1  IN         India  New Delhi   3.286  1252.00
# 2  CH         China    Beijing   9.597  1357.00
# 3  SA  South Africa   Pretoria   1.221    52.98

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv",skiprows=[2])
print(brick_df)
# Out:
#    ID       country    capital   area  population
# 0  BR        Brazil   Brasilia  8.516      200.40
# 1  IN         India  New Delhi  3.286     1252.00
# 2  CH         China    Beijing  9.597     1357.00
# 3  SA  South Africa   Pretoria  1.221       52.98

# %% [markdown]
# ## "index_col" used to convert an columns into index.

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv",index_col=3)
brick_df
# Out:
#         ID       country    capital  population
# area
# 8.516   BR        Brazil   Brasilia      200.40
# 17.100  RU        Russia     Moscow      143.50
# 3.286   IN         India  New Delhi     1252.00
# 9.597   CH         China    Beijing     1357.00
# 1.221   SA  South Africa   Pretoria       52.98

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv",index_col='country')
brick_df
# Out:
#               ID    capital    area  population
# country
# Brazil        BR   Brasilia   8.516      200.40
# Russia        RU     Moscow  17.100      143.50
# India         IN  New Delhi   3.286     1252.00
# China         CH    Beijing   9.597     1357.00
# South Africa  SA   Pretoria   1.221       52.98

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv")
brick_df
# Out:
#    ID       country    capital    area  population
# 0  BR        Brazil   Brasilia   8.516      200.40
# 1  RU        Russia     Moscow  17.100      143.50
# 2  IN         India  New Delhi   3.286     1252.00
# 3  CH         China    Beijing   9.597     1357.00
# 4  SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# ## "header" paameter to change header.

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv",header=1)
brick_df
# Out:
#    BR        Brazil   Brasilia   8.516    200.4
# 0  RU        Russia     Moscow  17.100   143.50
# 1  IN         India  New Delhi   3.286  1252.00
# 2  CH         China    Beijing   9.597  1357.00
# 3  SA  South Africa   Pretoria   1.221    52.98

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv")
brick_df
# Out:
#    ID       country    capital    area  population
# 0  BR        Brazil   Brasilia   8.516      200.40
# 1  RU        Russia     Moscow  17.100      143.50
# 2  IN         India  New Delhi   3.286     1252.00
# 3  CH         China    Beijing   9.597     1357.00
# 4  SA  South Africa   Pretoria   1.221       52.98

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv",header=None)
brick_df
# Out:
#     0             1          2      3           4
# 0  ID       country    capital   area  population
# 1  BR        Brazil   Brasilia  8.516       200.4
# 2  RU        Russia     Moscow   17.1       143.5
# 3  IN         India  New Delhi  3.286        1252
# 4  CH         China    Beijing  9.597        1357
# 5  SA  South Africa   Pretoria  1.221       52.98

# %% [markdown]
# ## "prefix parameter to change header name into string."

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv",header=None,prefix='columns')
brick_df
# Out:
#   columns0      columns1   columns2 columns3    columns4
# 0       ID       country    capital     area  population
# 1       BR        Brazil   Brasilia    8.516       200.4
# 2       RU        Russia     Moscow     17.1       143.5
# 3       IN         India  New Delhi    3.286        1252
# 4       CH         China    Beijing    9.597        1357
# 5       SA  South Africa   Pretoria    1.221       52.98

# %% [markdown]
# ## "Names" paameter used to provide specific names to columns.

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv")
print(brick_df)
# Out:
#    ID       country    capital    area  population
# 0  BR        Brazil   Brasilia   8.516      200.40
# 1  RU        Russia     Moscow  17.100      143.50
# 2  IN         India  New Delhi   3.286     1252.00
# 3  CH         China    Beijing   9.597     1357.00
# 4  SA  South Africa   Pretoria   1.221       52.98

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv",true_values=['Yes'])
print(brick_df)
# Out:
#    ID       country    capital    area  population
# 0  BR        Brazil   Brasilia   8.516      200.40
# 1  RU        Russia     Moscow  17.100      143.50
# 2  IN         India  New Delhi   3.286     1252.00
# 3  CH         China    Beijing   9.597     1357.00
# 4  SA  South Africa   Pretoria   1.221       52.98

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv")
print(brick_df)
# Out:
#    ID       country    capital    area  population
# 0  BR        Brazil   Brasilia   8.516      200.40
# 1  RU        Russia     Moscow  17.100      143.50
# 2  IN         India  New Delhi   3.286     1252.00
# 3  CH         China    Beijing   9.597     1357.00
# 4  SA  South Africa   Pretoria   1.221       52.98

# %%
brick_df=pd.read_csv("E://Datasets//GovtData//brics.csv",true_values=['Yes'],false_values=['No'])
print(brick_df)
# Out:
#    ID       country    capital    area  population
# 0  BR        Brazil   Brasilia   8.516      200.40
# 1  RU        Russia     Moscow  17.100      143.50
# 2  IN         India  New Delhi   3.286     1252.00
# 3  CH         China    Beijing   9.597     1357.00
# 4  SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# ## Sort_values method

# %%
pokemon=pd.read_csv("E://Datasets//New Dataset//Pokemon.csv",usecols=['Name'])
pokemon.head(10)
# Out:
#                         Name
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
# 5                 Charmeleon
# 6                  Charizard
# 7  CharizardMega Charizard X
# 8  CharizardMega Charizard Y
# 9                   Squirtle

# %%
pokemon.sort_values(by='Name')
# Out:
#                         Name
# 510                Abomasnow
# 511  AbomasnowMega Abomasnow
# 68                      Abra
# 392                    Absol
# 393          AbsolMega Absol
# ..                       ...
# 632                  Zoroark
# 631                    Zorua
# 46                     Zubat
# 695                 Zweilous
# 794         Zygarde50% Forme
#
# [800 rows x 1 columns]

# %%
pokemon.sort_values(by='Name',ascending=False)
# Out:
#                         Name
# 794         Zygarde50% Forme
# 695                 Zweilous
# 46                     Zubat
# 631                    Zorua
# 632                  Zoroark
# ..                       ...
# 393          AbsolMega Absol
# 392                    Absol
# 68                      Abra
# 511  AbomasnowMega Abomasnow
# 510                Abomasnow
#
# [800 rows x 1 columns]

# %% [markdown]
# ## Index_sort

# %%
pokemon
# Out:
#                       Name
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# ..                     ...
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
#
# [800 rows x 1 columns]

# %%
pokemon.sort_values(by='Name',ascending=False)
# Out:
#                         Name
# 794         Zygarde50% Forme
# 695                 Zweilous
# 46                     Zubat
# 631                    Zorua
# 632                  Zoroark
# ..                       ...
# 393          AbsolMega Absol
# 392                    Absol
# 68                      Abra
# 511  AbomasnowMega Abomasnow
# 510                Abomasnow
#
# [800 rows x 1 columns]

# %%
pokemon.sort_index(ascending=False).head(10)
# Out:
#                     Name
# 799            Volcanion
# 798   HoopaHoopa Unbound
# 797  HoopaHoopa Confined
# 796  DiancieMega Diancie
# 795              Diancie
# 794     Zygarde50% Forme
# 793              Yveltal
# 792              Xerneas
# 791              Noivern
# 790               Noibat

# %%
nba=pd.read_csv("E://Datasets//New Dataset//nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.sort_values('Name',ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0    6-8
# ..               ...                     ...     ...      ...   ...    ...
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
nba.sort_values('Age',ascending=False)
# Out:
#                Name                    Team  Number Position   Age Height  \
# 304    Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3
# 400   Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 298      Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
# 261    Vince Carter       Memphis Grizzlies    15.0       SG  39.0    6-6
# 102  Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3
# ..              ...                     ...     ...      ...   ...    ...
# 401      Tyus Jones  Minnesota Timberwolves     1.0       PG  20.0    6-2
# 60   Christian Wood      Philadelphia 76ers    35.0       PF  20.0   6-11
# 226   Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0    6-6
# 122    Devin Booker            Phoenix Suns     1.0       SG  19.0    6-6
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College     Salary
# 304   200.0            Utah   250750.0
# ...

# %%
nba.sort_index(ascending=False,na_position='last').tail()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#              College     Salary
# 4                NaN  5000000.0
# 3      Georgia State  1148640.0
# 2  Boston University        NaN
# 1          Marquette  6796117.0
# 0              Texas  7730337.0

# %%
nba.sort_values(['Name','Position','Salary'],ascending=False,inplace=True)

# %%
nba.sort_index(ascending=False)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#                College     Salary
# 457                NaN        NaN
# ...

# %%
nba.sort_values(['Name','Position','Salary'],ascending=[False,True,False],inplace=True)
nba
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0    6-8
# ..               ...                     ...     ...      ...   ...    ...
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight         College      Salary
# ...

# %%
nba.sort_index(ascending=False,inplace=True)
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#                College     Salary
# 457                NaN        NaN
# ...

# %% [markdown]
# ## max() and min() function.

# %%
nba.max()
# Out:
# Number          99.0
# Age             40.0
# Weight         307.0
# Salary    25000000.0
# dtype: float64

# %%
nba.min()
# Out:
# Number        0.0
# Age          19.0
# Weight      161.0
# Salary    30888.0
# dtype: float64

# %% [markdown]
# ## value_count()

# %%
nba.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-b0bb5ecb79b4> in <module>
# ----> 1 nba.value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'
